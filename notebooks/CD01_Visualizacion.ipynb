# %% [markdown]
# ## Máster en Big Data y Data Science
#
# ### Metodologías de gestión y diseño de proyectos de big data
#
# #### AP1 - Visualización de los datos
#
# ---
#
# En esta libreta se realiza una visualización básica de los datos del escenario.

# %%
# Importación de librerías y supresión de advertencias
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración general
sns.set(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"] = (8, 5)

warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore',category=UserWarning)

# %% [markdown]
# Lectura de los datos desde el directorio data/raw

# %%
# Lectura de los datos de créditos
df_creditos = pd.read_csv("../data/raw/datos_creditos.csv", sep=";")
df_creditos.head(5)
# Out:
#     id_cliente  edad  importe_solicitado  duracion_credito  \
# 0  713061558.0    22               35000                 3
# 1  768805383.0    21                1000                 2
# 2  818770008.0    25                5500                 3
# 3  713982108.0    23               35000                 2
# 4  710821833.0    24               35000                 4
#
#    antiguedad_empleado situacion_vivienda  ingresos objetivo_credito  \
# 0                123.0           ALQUILER     59000         PERSONAL
# 1                  5.0             PROPIA      9600        EDUCACIÓN
# 2                  1.0           HIPOTECA      9600            SALUD
# 3                  4.0           ALQUILER     65500            SALUD
# 4                  8.0           ALQUILER     54400            SALUD
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago
# 0         0.59         16.02               1          Y
# 1         0.10         11.14               0          N
# 2         0.57         12.87               1          N
# 3         0.53         15.23               1          N
# 4         0.55         14.27               1          Y

# %%
# Lectura de los datos de tarjetas
df_tarjetas = pd.read_csv("../data/raw/datos_tarjetas.csv", sep=";")
display(df_tarjetas.head(5))
# Out:
#     id_cliente  antiguedad_cliente estado_civil estado_cliente  \
# 0  713061558.0                36.0       CASADO         ACTIVO
# 1  768805383.0                39.0       CASADO         ACTIVO
# 2  818770008.0                44.0      SOLTERO         ACTIVO
# 3  713982108.0                36.0       CASADO         ACTIVO
# 4  710821833.0                54.0       CASADO         ACTIVO
#
#    gastos_ult_12m genero  limite_credito_tc         nivel_educativo  \
# 0          1088.0      M             4010.0  UNIVERSITARIO_COMPLETO
# 1          1144.0      M            12691.0     SECUNDARIO_COMPLETO
# 2          1291.0      F             8256.0  UNIVERSITARIO_COMPLETO
# 3          1887.0      M             3418.0  UNIVERSITARIO_COMPLETO
# 4          1314.0      M             9095.0             DESCONOCIDO
#
#   nivel_tarjeta  operaciones_ult_12m  personas_a_cargo
# 0          Blue                 24.0               2.0
# 1          Blue                 42.0               3.0
# 2          Blue                 33.0               5.0
# 3          Blue                 20.0               3.0
# 4          Blue                 26.0               1.0

# %% [markdown]
# Visualización de algunas propiedades del dataset

# %%
# Dimensiones del dataset
print("Dimensiones del dataset de creditos:")
print(f'El dataset tiene {df_creditos.shape[0]} filas y {df_creditos.shape[1]} columnas.')
print("\nDimensiones del dataset de tarjetas:")
print(f'El dataset tiene {df_tarjetas.shape[0]} filas y {df_tarjetas.shape[1]} columnas.')
# Out:
# Dimensiones del dataset de creditos:
# El dataset tiene 10127 filas y 12 columnas.
#
# Dimensiones del dataset de tarjetas:
# El dataset tiene 10127 filas y 11 columnas.

# %%
# Se obtiene una descripción estadística de las columnas numéricas de cada DataFrame
print("\nDescripción general del dataset de créditos:")
display(df_creditos.describe())
print("\nDescripción general del dataset de tarjetas:")
display(df_tarjetas.describe())
# Out:
# Descripción general del dataset de créditos:
#          id_cliente          edad  importe_solicitado  duracion_credito  \
# count  1.012700e+04  10127.000000        10127.000000      10127.000000
# mean   7.391776e+08     23.572726         8138.733090          2.995556
# std    3.690378e+07      2.664686         5740.106782          0.817230
# min    7.080821e+08     20.000000          500.000000          2.000000
# 25%    7.130368e+08     22.000000         4425.000000          2.000000
# 50%    7.179264e+08     23.000000         6500.000000          3.000000
# 75%    7.731435e+08     25.000000        10000.000000          4.000000
# max    8.283431e+08    144.000000        35000.000000          4.000000
#
#        antiguedad_empleado       ingresos   pct_ingreso  tasa_interes  \
# count          9790.000000   10127.000000  10127.000000   9215.000000
# mean              3.938509   50381.897600      0.177226     10.979427
# std               3.320165   28785.536935      0.109784      3.204760
# min               0.000000    9600.000000      0.010000      5.420000
# 25%               2.000000   33600.000000      0.100000      7.900000
# 50%               4.000000   46000.000000      0.150000     10.990000
# 75%               6.000000   59790.500000      0.240000     13.430000
# max             123.000000  500000.000000      0.830000     22.110000
#
#        estado_credito
# count    10127.000000
# mean         0.246075
# std          0.430744
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Descripción general del dataset de tarjetas:
#          id_cliente  antiguedad_cliente  gastos_ult_12m  limite_credito_tc  \
# count  1.012700e+04        10127.000000    10127.000000       10127.000000
# mean   7.391776e+08           35.928409     4404.086304        8631.953698
# std    3.690378e+07            7.986416     3397.129254        9088.776650
# min    7.080821e+08           13.000000      510.000000        1438.300000
# 25%    7.130368e+08           31.000000     2155.500000        2555.000000
# 50%    7.179264e+08           36.000000     3899.000000        4549.000000
# 75%    7.731435e+08           40.000000     4741.000000       11067.500000
# max    8.283431e+08           56.000000    18484.000000       34516.000000
#
#        operaciones_ult_12m  personas_a_cargo
# count         10127.000000      10127.000000
# mean             64.858695          2.346203
# std              23.472570          1.298908
# min              10.000000          0.000000
# 25%              45.000000          1.000000
# 50%              67.000000          2.000000
# 75%              81.000000          3.000000
# max             139.000000          5.000000

# %%
# Se obtiene una descripción estadística de las columnas categóricas del DataFrame
print("\nDescripción de las columnas categóricas del dataset de créditos:")
display(df_creditos.describe(include='object'))
print("\nDescripción de las columnas categóricas del dataset de tarjetas:") 
display(df_tarjetas.describe(include='object'))
# Out:
# Descripción de las columnas categóricas del dataset de créditos:
#        situacion_vivienda objetivo_credito falta_pago
# count               10127            10127      10127
# unique                  4                6          2
# top              ALQUILER        EDUCACIÓN          N
# freq                 6125             2328       8359
# Descripción de las columnas categóricas del dataset de tarjetas:
#        estado_civil estado_cliente genero         nivel_educativo  \
# count         10127          10127  10127                   10127
# unique            4              2      2                       6
# top          CASADO         ACTIVO      F  UNIVERSITARIO_COMPLETO
# freq           4687           8500   5358                    3128
#
#        nivel_tarjeta
# count          10127
# unique             4
# top             Blue
# freq            9436

# %%
# Información del DataFrame de créditos
print("\nInformación del dataset de créditos:") 
df_creditos.info()
# Out:
# Información del dataset de créditos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_cliente           10127 non-null  float64
#  1   edad                 10127 non-null  int64
#  2   importe_solicitado   10127 non-null  int64
#  3   duracion_credito     10127 non-null  int64
#  4   antiguedad_empleado  9790 non-null   float64
#  5   situacion_vivienda   10127 non-null  object
#  6   ingresos             10127 non-null  int64
#  7   objetivo_credito     10127 non-null  object
#  8   pct_ingreso          10127 non-null  float64
#  9   tasa_interes         9215 non-null   float64
#  10  estado_credito       10127 non-null  int64
#  11  falta_pago           10127 non-null  object
# dtypes: float64(4), int64(5), object(3)
# memory usage: 949.5+ KB

# %%
# Información del DataFrame de tarjetas
print("\nInformación del dataset de tarjetas:") 
df_tarjetas.info()
# Out:
# Información del dataset de tarjetas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_cliente           10127 non-null  float64
#  1   antiguedad_cliente   10127 non-null  float64
#  2   estado_civil         10127 non-null  object
#  3   estado_cliente       10127 non-null  object
#  4   gastos_ult_12m       10127 non-null  float64
#  5   genero               10127 non-null  object
#  6   limite_credito_tc    10127 non-null  float64
#  7   nivel_educativo      10127 non-null  object
#  8   nivel_tarjeta        10127 non-null  object
#  9   operaciones_ult_12m  10127 non-null  float64
#  10  personas_a_cargo     10127 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 870.4+ KB

# %% [markdown]
# ### Distribución de la variable objetivo
#
# Es importante observar el balance de clases en la variable `falta_pago` (crédito que presentó o no mora).
# Esto permite anticipar si habrá desbalance que afecte el modelo predictivo.

# %%
sns.countplot(x="falta_pago", data=df_creditos)
plt.title("Distribución de la variable objetivo (mora)")
plt.xlabel("¿Presentó mora el cliente?")
plt.ylabel("Cantidad de clientes")
plt.show()

df_creditos["falta_pago"].value_counts(normalize=True).mul(100).round(2)
# Out:
# falta_pago
# N    82.54
# Y    17.46
# Name: proportion, dtype: float64

# %% [markdown]
# ### Distribución de variables categóricas
#
# Las variables categóricas permiten entender mejor la composición del conjunto de clientes.

# %%
categorical_cols = df_creditos.select_dtypes(include=["object"]).columns.drop("falta_pago")

print("\nDistribución de las variables categóricas del dataset de créditos:")

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    order = df_creditos[col].value_counts().index
    sns.countplot(y=col, data=df_creditos, order=order)
    plt.title(f"Distribución de {col}")
    plt.xlabel("Cantidad")
    plt.ylabel(col)
    plt.show()
# Out:
# Distribución de las variables categóricas del dataset de créditos:

# %%
categorical_cols = df_tarjetas.select_dtypes(include=["object"])

print("\nDistribución de las variables categóricas del dataset de tarjetas:")

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    order = df_tarjetas[col].value_counts().index
    sns.countplot(y=col, data=df_tarjetas, order=order)
    plt.title(f"Distribución de {col}")
    plt.xlabel("Cantidad")
    plt.ylabel(col)
    plt.show()
# Out:
# Distribución de las variables categóricas del dataset de tarjetas:

# %% [markdown]
# ### Correlación entre variables numéricas
#
# La correlación entre variables numéricas permite identificar relaciones lineales entre ellas y, consiguientemente, patrones que pueden ser útiles en modelos predictivos.

# %%
num_df = df_creditos.select_dtypes(include=['float64', 'int64'])
corr = num_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de correlaciones - Créditos')
plt.show()

# %%
num_df = df_tarjetas.select_dtypes(include=['float64', 'int64'])
corr = num_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de correlaciones - Tarjetas')
plt.show()

# %% [markdown]
# ### Listado de columnas de cada dataset
#
# Finalmente, se realiza una visualización general de las columnas de cada dataset para su registro.

# %%
def reporte_descripcion_dataset(df):
    columnas = df.columns
    print("Columnas del dataset:\n")
    for col in columnas:
        print(col)

# %%
print("Descripción del dataset 'datos_creditos'")
reporte_descripcion_dataset(df_creditos)
# Out:
# Descripción del dataset 'datos_creditos'
# Columnas del dataset:
#
# id_cliente
# edad
# importe_solicitado
# duracion_credito
# antiguedad_empleado
# situacion_vivienda
# ingresos
# objetivo_credito
# pct_ingreso
# tasa_interes
# estado_credito
# falta_pago

# %%
print("Descripción del dataset 'datos_tarjetas'")
reporte_descripcion_dataset(df_tarjetas)
# Out:
# Descripción del dataset 'datos_tarjetas'
# Columnas del dataset:
#
# id_cliente
# antiguedad_cliente
# estado_civil
# estado_cliente
# gastos_ult_12m
# genero
# limite_credito_tc
# nivel_educativo
# nivel_tarjeta
# operaciones_ult_12m
# personas_a_cargo
