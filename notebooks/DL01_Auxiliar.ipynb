# %%
import pandas as pd

# %%
# Lectura de los datos
df = pd.read_csv('data/processed/datos_integrados.csv')
df.head(5)
# Out:
#    duracion_credito situacion_vivienda  ingresos objetivo_credito  \
# 0                 3           ALQUILER     59000         PERSONAL
# 1                 2             PROPIA      9600        EDUCACIÓN
# 2                 3           HIPOTECA      9600            SALUD
# 3                 2           ALQUILER     65500            SALUD
# 4                 4           ALQUILER     54400            SALUD
#
#    pct_ingreso  tasa_interes  estado_credito falta_pago  antiguedad_cliente  \
# 0         0.59         16.02               1          Y                36.0
# 1         0.10         11.14               0          N                39.0
# 2         0.57         12.87               1          N                44.0
# 3         0.53         15.23               1          N                36.0
# 4         0.55         14.27               1          Y                54.0
#
#   estado_civil  ... genero limite_credito_tc         nivel_educativo  \
# ...

# %%
resumen  = df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10123 entries, 0 to 10122
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   duracion_credito            10123 non-null  int64
#  1   situacion_vivienda          10123 non-null  str
#  2   ingresos                    10123 non-null  int64
#  3   objetivo_credito            10123 non-null  str
#  4   pct_ingreso                 10123 non-null  float64
#  5   tasa_interes                10123 non-null  float64
#  6   estado_credito              10123 non-null  int64
#  7   falta_pago                  10123 non-null  str
#  8   antiguedad_cliente          10123 non-null  float64
#  9   estado_civil                10123 non-null  str
#  10  estado_cliente              10123 non-null  str
#  11  genero                      10123 non-null  str
#  12  limite_credito_tc           10123 non-null  float64
# ...

# %%
print(df.loc[1])
# Out:
# duracion_credito                                2
# situacion_vivienda                         PROPIA
# ingresos                                     9600
# objetivo_credito                        EDUCACIÓN
# pct_ingreso                                   0.1
# tasa_interes                                11.14
# estado_credito                                  0
# falta_pago                                      N
# antiguedad_cliente                           39.0
# estado_civil                               CASADO
# estado_cliente                             ACTIVO
# genero                                          M
# limite_credito_tc                         12691.0
# nivel_educativo               SECUNDARIO_COMPLETO
# personas_a_cargo                              3.0
# capacidad_pago                           0.104167
# ratio_endeudamiento                       0.09434
# operaciones_mensuales                         3.5
# gasto_transaccion_promedio              27.238095
# ...
